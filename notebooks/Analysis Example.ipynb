# %%
from konfuzio_sdk.analysis import Analysis, Plot

# %%
analysis = Analysis(1377)
# Out:
# 2023-09-15 18:58:38,091 [konfuzio_sdk.api    ] [MainThread] [INFO    ] [get_meta_of_files   ][0431] Iterate on paginated https://app.konfuzio.com/api/projects/1377/docs/?limit=1000.
# 2023-09-15 18:58:40,306 [konfuzio_sdk.api    ] [MainThread] [INFO    ] [get_meta_of_files   ][0431] Iterate on paginated https://app.konfuzio.com/api/projects/1377/docs/?limit=1000&offset=1000.
# 2023-09-15 18:58:41,594 [konfuzio_sdk.api    ] [MainThread] [INFO    ] [get_meta_of_files   ][0431] Iterate on paginated https://app.konfuzio.com/api/projects/1377/docs/?limit=1000&offset=2000.
# 2023-09-15 18:58:42,835 [konfuzio_sdk.api    ] [MainThread] [INFO    ] [get_meta_of_files   ][0431] Iterate on paginated https://app.konfuzio.com/api/projects/1377/docs/?limit=1000&offset=3000.
# 2023-09-15 18:58:44,072 [konfuzio_sdk.api    ] [MainThread] [INFO    ] [get_meta_of_files   ][0431] Iterate on paginated https://app.konfuzio.com/api/projects/1377/docs/?limit=1000&offset=4000.
# ...

# %%
cdata = analysis.count_test_docs_by_label('Company_name')
# Out:
# 2023-09-15 19:00:33,231 [konfuzio_sdk.data   ] [MainThread] [WARNING ] [offset_string       ][2326] You use offset string on Annotation (https://app.konfuzio.com/a/12198761) Company name (234, 274), (307, 328) level which is legacy.
# 2023-09-15 19:00:33,232 [konfuzio_sdk.data   ] [MainThread] [WARNING ] [offset_string       ][2326] You use offset string on Annotation (https://app.konfuzio.com/a/12198767) Company name (113, 149), (170, 195) level which is legacy.
# 2023-09-15 19:00:33,234 [konfuzio_sdk.data   ] [MainThread] [WARNING ] [offset_string       ][2326] You use offset string on Annotation (https://app.konfuzio.com/a/18694709) Company name (256, 304), (404, 422) level which is legacy.
# 2023-09-15 19:00:33,236 [konfuzio_sdk.data   ] [MainThread] [WARNING ] [offset_string       ][2326] You use offset string on Annotation (https://app.konfuzio.com/a/12199003) Company name (1866, 1893), (1960, 1975) level which is legacy.
# ...

# %%
Plot.plot_doc_counts(cdata, "Company")
